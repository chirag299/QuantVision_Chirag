# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi1603/QuantVision/blob/main/Assigment2_ADITI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly yfinance

# %%
import yfinance as yf
from datetime import date, timedelta

ticker_symbol = "TSLA"
enddate = date.today()
startdate = enddate - timedelta(days=180)
stockdata = yf.download(
    ticker_symbol,
    start = startdate,
    end = enddate,
    interval ="1d"
)
if isinstance(stockdata.columns, pd.MultiIndex):
  stockdata.columns = stockdata.columns.droplevel(1)

print(f"\n Downloaded historical data for {ticker_symbol}.")
print(f"Data period = {startdate} to {enddate}.")
print("\n First 5 rows of the data:")
print(stockdata.head())

print("\n Last 5 rows of the data:")
print(stockdata.tail())
# Out:
# /tmp/ipython-input-1134608705.py:7: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
#  Downloaded historical data for TSLA.
# Data period = 2025-06-14 to 2025-12-11.
#
#  First 5 rows of the data:
# Price            Close        High         Low        Open     Volume
# Date
# 2025-06-16  329.130005  332.049988  326.410004  331.290009   83925900
# 2025-06-17  316.350006  327.260010  314.739990  326.089996   88282700
# 2025-06-18  322.049988  329.320007  315.450012  317.309998   95137700
# 2025-06-20  322.160004  332.359985  317.779999  327.950012  108688000
# 2025-06-23  348.679993  357.540009  327.480011  327.540009  190716800
#
#  Last 5 rows of the data:
# Price            Close        High         Low        Open    Volume
# Date
# 2025-12-04  454.529999  454.630005  445.390015  449.940002  71906500
# 2025-12-05  455.000000  458.869995  451.660004  453.029999  56427500
# ...

# %%
import plotly.graph_objects as go
import pandas as pd
candlestick = go.Candlestick(
    x = stockdata.index,
    open = stockdata['Open'],
    high = stockdata['High'],
    low = stockdata['Low'],
    close = stockdata['Close'],
    name = 'Market Data'
)

fig = go.Figure(data=[candlestick])
chart_title = f'{ticker_symbol} Candlestick chart (last 6 months)'
fig.update_layout(
    title=chart_title,
    xaxis_title='Data',
    yaxis_title= 'Stock price(USD)',
    xaxis_rangeslider_visible = False,
    hovermode='x unified',
    template = 'plotly_dark'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# DATE OF THE PATTERN OCCURED : OCTOBER 3, 2025
# NAME OF THE PATTERN : BULLISH ENGULFING PATTERN
# THE PRICE WENT UP OVER THE NEXT FEW DAYS IMMEDIATELY AFTER THE ENGULFING CANDLE
